# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
beras = 11400 #perkilo
minyak = 12700 #perliter
ayam = 3400 #pergram
telur = 21800 #per100kg
popok = 27000 #per pcs
sabun_cuci = 1800 #per100gr
buah_anggur = 3800 #per100gr
roti_tawar = 8500 #per100gr
tisu = 6400 #per pcs
mie_instan = 2200 #per pcs

print("=== Belanjaan Tia ===")
beras_tia = 4
ayam_tia = 20
telur_tia = 3
sabun_cuci_tia = 5 #gr
buah_anggur_tia = 4
roti_tawar_tia = 2 #gr
mie_instan_tia = 12
jb_tia = (beras_tia * beras) + (ayam_tia * ayam) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
diskon = 80 #kebalikan dari 20
jb_diskon_tia = (jb_tia / 100) * diskon
print("Maka jumlah belanjaan tia " + str(jb_tia) + " rupiah")
print("Maka jumlah belanjaan tia setelah mendapatkan diskon adalah " +  str(jb_diskon_tia))
print("")
print("")

print("=== Belanjaan Hana ===")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5 
sabun_cuci_hana = 3
buah_anggur_hana = 8
roti_tawar_hana = 3
tisu_hana = 2
mie_instan_hana = 20
jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam) + (telur_hana * telur ) + (sabun_cuci_hana * sabun_cuci ) + (buah_anggur_hana * buah_anggur) + (roti_tawar_hana * roti_tawar) + (tisu_hana * tisu) + (mie_instan_hana * mie_instan)
diskon = 75 #kebalikan dari 25
jb_diskon_hana = (jb_hana / 100) * diskon
print("Maka jumlah belanjaan hana " + str(jb_hana) + " rupiah")
print("Maka jumlah belanjaan hana setelah mendapatkan diskon adalah " +  str(jb_diskon_hana))
print("")
print("")

print("=== Belanjaan Widia ===")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_anggur_widia = 0.5
tisu_widia = 3
mie_instan_widia = 16
jb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (buah_anggur_hana * buah_anggur) + (tisu_widia * tisu) + (mie_instan_widia * mie_instan)
diskon = 90 #kebalikan dari 10
jb_diskon_widia = (jb_widia / 100) * diskon
print("Maka jumlah belanjaan widia " + str(jb_widia) + " rupiah")
print("Maka jumlah belanjaan widia setelah mendapatkan diskon adalah " +  str(jb_diskon_widia))
print("")
print("")

print("=== Belanjaan Romi ===")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_cuci_romi = 8
mie_instan_romi = 8
jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_cuci_romi * sabun_cuci) + (mie_instan_romi * mie_instan)
diskon = 85 #kebalikan dari 15
jb_diskon_romi = (jb_romi / 100) * diskon
print("Maka jumlah belanjaan Romi " + str(jb_romi) + " rupiah")
print("Maka jumlah belanjaan Romi setelah mendapatkan diskon adalah " +  str(jb_diskon_romi))
print("")
print("")

print("=== Belanjaan Samsul ===")
ayam_samsul = 30
telur_samsul = 4
popok_samsul = 2
buah_anggur_samsul = 0.7
tisu_samsul = 5
mie_instan_samsul = 10
jb_samsul = (ayam_samsul * ayam) + (telur_samsul * telur) + (popok_samsul * popok) + (buah_anggur_samsul * buah_anggur) + (tisu_samsul * tisu) + (mie_instan_samsul * mie_instan)
diskon = 85 #kebalikan dari 15
jb_diskon_samsul = (jb_samsul / 100) * diskon
print("Maka jumlah belanjaan Samsul " + str(jb_samsul) + " rupiah")
print("Maka jumlah belanjaan Samsul setelah mendapatkan diskon adalah " +  str(jb_diskon_samsul))
print("")
print("")

print("=== Belanjaan Dimas ===")
ayam_dimas = 5
popok_dimas = 5
sabun_cuci_dimas = 4
buah_anggur_dimas = 3
roti_tawar_dimas = 5
mie_instan_dimas = 6
jb_dimas = (ayam_dimas * ayam) + (popok_dimas * popok) + (sabun_cuci_dimas * sabun_cuci) + (buah_anggur_dimas * buah_anggur) + (roti_tawar_dimas * roti_tawar) + (mie_instan_dimas * mie_instan)
diskon = 85 #kebalikan dari 15
jb_diskon_dimas = (jb_dimas / 100) * diskon
print("Maka jumlah belanjaan Dimas " + str(jb_dimas) + " rupiah")
print("Maka jumlah belanjaan Dimas setelah mendapatkan diskon adalah " +  str(jb_diskon_dimas))

print("=== Yang Mendapatkan Diskon 10% ===")
nama = ("Widi")
print(nama[0])
print("")

print("=== Yang Mendapatkan Diskon 10% ===")
nama = ("Widia")
print(nama[0])
print(nama[1])

print("")

print("=== Yang Mendapatkan Diskon 15% ===")
nama = ("Romi", "Samsul", "Dimas")
print(nama[0])
print(nama[1])
print(nama[2])
print("")

print("=== Yang Mendapatkan Miskon 20% ===")
nama = ["Tia"]
print(nama[0])
print("")


print("=== Yang Mendapatkan Diskon 25% ===")
nama = ["Hana"]
print(nama[0])
print("")

print("=== Belanjaan Yang Paling Besar Adalah ===")
nama = ["Hana"]
print(nama[0])
# Out:
# === Belanjaan Tia ===
# Maka jumlah belanjaan tia 246600 rupiah
# Maka jumlah belanjaan tia setelah mendapatkan diskon adalah 197280.0
#
#
# === Belanjaan Hana ===
# Maka jumlah belanjaan hana 193200.0 rupiah
# Maka jumlah belanjaan hana setelah mendapatkan diskon adalah 144900.0
#
#
# === Belanjaan Widia ===
# Maka jumlah belanjaan widia 130700 rupiah
# Maka jumlah belanjaan widia setelah mendapatkan diskon adalah 117630.0
#
#
# === Belanjaan Romi ===
# Maka jumlah belanjaan Romi 221700 rupiah
# Maka jumlah belanjaan Romi setelah mendapatkan diskon adalah 188445.0
#
#
# === Belanjaan Samsul ===
# Maka jumlah belanjaan Samsul 299860.0 rupiah
# Maka jumlah belanjaan Samsul setelah mendapatkan diskon adalah 254881.0
#
#
# === Belanjaan Dimas ===
# Maka jumlah belanjaan Dimas 226300 rupiah
# Maka jumlah belanjaan Dimas setelah mendapatkan diskon adalah 192355.0
# === Yang Mendapatkan Diskon 10% ===
# W
#
# === Yang Mendapatkan Diskon 10% ===
# W
# i
#
# ...
