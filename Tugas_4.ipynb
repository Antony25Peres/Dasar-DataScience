# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
burger =	24000
pizza	= 52000
dimsum = 30000
ekkado	= 7500
milkshake	= 10000
eskrim	= 15000

print("=== Soal 1 ===")
burger_semua = 6
pizza_semua = 3
dimsum_semua = 4
eskrim_semua = 5
milkshake_semua = 2
ekkado_semua = 4
js = (burger_semua * burger) + (pizza_semua * pizza) + (dimsum_semua * dimsum) + (eskrim_semua * eskrim) + (milkshake_semua * milkshake) + (ekkado_semua * ekkado)
jm = (burger_semua + pizza_semua + dimsum_semua + eskrim_semua + milkshake_semua + ekkado_semua)
print("Jadi Total Harga Dari Semua Makanan  adalah rp. " + str(js))


print("=== Soal 2 ===")
f1 = (burger_semua / jm) * 100
f2 = (pizza_semua / jm) * 100
f3 = (dimsum_semua / jm) * 100
f4 = (eskrim_semua / jm) * 100
f5 = (milkshake_semua / jm) * 100
f6 = (ekkado_semua / jm) * 100

print("burger " + str(f1) +'%')
print("pizza " + str(f2) +'%')
print("dimsum " + str(f3) +'%')
print("eskrim " + str(f4) +'%')
print("milkshake " + str(f5) +'%')
print("ekkado " + str(f6) +'%')
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
makanan = ['burger', 'pizza', 'dimsumi', 'eskrim', 'milkshake', 'ekkado']
harga = [25.0, 12.5, 16.666666666666664, 20.833333333333336,  8.333333333333332, 16.666666666666664]
ax.pie(harga,labels=makanan,autopct='%1.2f%%')
plt.show()
print("")
print("")


print("=== Soal 3 ===")
print("     Ahmad     ")
burger = 4
pizza = 2
jarak = 7.5
uang_a = 200000
jml_a = (0.70 * ((burger * 24000) + (pizza * 52000))) + (7.5 * 2000) - 5000
disc = uang_a - jml_a
print(" maka total belanjaan Ahmad adalah : rp. " + str(jml_a))
print(" maka total kembalian Ahmad adalah : rp. " + str(disc))
print()

print("     Beni     ")
dimsum_b = 3
eskrim_b = 1
milkshake_b = 2
uang_b = 150000
jml_b = (0.70 * ((dimsum_b * 30000) + (eskrim_b * 15000) + (milkshake_b * 10000))) + (4 * 1800) - 5000
disc = uang_b - jml_b
print(" maka total belanjaan Beni adalah : rp. " + str(jml_b))
print(" maka total kembalian Beni adalah : rp. " + str(disc))
print()

print("     Citra     ")
eskrim_c = 3
uang_c = 60000
jml_c = (eskrim_c * 15000) + (8 * 2000) - 5000
disc = uang_c - jml_c
print(" maka total belanjaan Citra adalah : rp. " + str(jml_c))
print(" maka total kembalian Citra adalah : rp. " + str(disc))
print()

print("     Dadang     ")
burger = 2
dimsum = 1
uang_d = 100000
jml_d = (0.80 * ((burger * 24000) + (dimsum * 30000))) + (5 * 1800) - 5000
disc = uang_d - jml_d
print(" maka total belanjaan Dadang adalah : rp. " + str(jml_d))
print(" maka total kembalian Dadang adalah : rp. " + str(disc))
print()


print("     Epen     ")
ekkado = 4
eskrim = 1
pizza = 1
uang_e = 100000
jml_e = (0.70 * ((ekkado * 7500) + (eskrim * 15000) + (pizza * 52000))) + (12 * 2200) - 5000
disc = uang_e - jml_e
print(" maka total belanjaan Epen adalah : rp. " + str(jml_e))
print(" maka total kembalian Epen adalah : rp. " + str(disc))
print()

print("=== Soal 4 ===")
burger = 4
pizza = 2
jml_a = (0.30 * ((burger * 24000) + (pizza * 52000))) + 5000
print(" maka jumlah potongan Ahmad  : rp. " + str(jml_a))

dimsum_b = 3
eskrim_b = 1
milkshake_b = 2
jml_b = (0.30 * ((dimsum_b * 30000) + (eskrim_b * 15000) + (milkshake_b * 10000))) + 5000
print(" maka jumlah potongan Beni   : rp. " + str(jml_b))

eskrim_c = 3
jml_c = (0.20 * (eskrim_c * 15000)) - 4000
print(" maka jumlah potongan Citra  : rp. " + str(jml_c))

burger = 2
dimsum = 1
jml_d = (0.30 * ((burger * 24000) + (dimsum * 30000))) +  5000
print(" maka jumlah potongan Dadang : rp. " + str(jml_d))

ekkado = 4
eskrim = 1
pizza = 1
jml_e = (0.30 * ((ekkado * 7500) + (eskrim * 15000) + (pizza * 52000))) + 5000
print(" maka jumlah potongan Epen   : rp. " + str(jml_e))

print("=== Soal 5 ===")

jarak = (7.5 * 2000) + (4 * 1800) + (8 * 2000) + (5 * 1800) + (12 * 2200)
print(" maka jumlah potongan Epen   : rp. " + str(jarak))
